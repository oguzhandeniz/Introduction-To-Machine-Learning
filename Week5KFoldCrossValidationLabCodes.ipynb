# %%
from sklearn.datasets import load_iris
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
iris = load_iris()
X,y = iris.data, iris.target

# %%
kf=KFold(n_splits=5 , shuffle=True , random_state=42)

# %%
model=LinearRegression()

# %%
scores = []
for train_index,test_index in kf.split(X):
    x_train,x_test=X[train_index],X[test_index]  
    y_train,y_test=y[train_index],y[test_index] 
    
    model.fit(x_train,y_train)
    
    y_pred=model.predict(x_test)
    
    score=mean_squared_error(y_test,y_pred)
    scores.append(score)

# %%
mean_score=np.mean(scores)

# %%
print("K Fold Cross Validation",scores)
print("Ortalama Hata Skoru",mean_score)
# Out:
# K Fold Cross Validation [0.037113794407976915, 0.042877331697643635, 0.05339513046889763, 0.06316425044891773, 0.047794600654438316]
# Ortalama Hata Skoru 0.04886902153557484
